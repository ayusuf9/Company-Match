# %%
import pandas as pd

# %%
df_usa = pd.read_excel("us-databreach.xlsx", engine="openpyxl")
df_canada = pd.read_excel("canada-databreach.xlsx", engine="openpyxl")
df_IQFirms = pd.read_excel("CapitalIQ_Firms_Canada.xlsx", engine="openpyxl")

# %%
df_usa.head()
# Out:
#    ID             Name of Entity Source Organization Type  \
# 0   1       STRATA Trust Company     CA               BSF
# 1   2       Gannett Company Inc.     IA               BSO
# 2   4     Bed Bath & Beyond Inc.     ME               BSR
# 3   5  Angola Wire Products Inc.     IN               BSO
# 4   6  State Industrial Products     ME               BSO
#
#                        Organization Type Explanation breach_location_street  \
# 0  STRATA Trust Company is a trust company, which...     7901 Woodway Drive
# 1  Gannett Company, Inc. is primarily a media com...  7950 Jones Branch Dr.
# 2  Bed Bath & Beyond Inc. is a retail business, w...                   UNKN
# 3  Angola Wire Products Inc. appears to be a manu...                   UNKN
# 4  State Industrial Products does not clearly fit...                   UNKN
#
#   breach_location_city breach_location_state breach_location_ZIP  \
# 0                 Waco                 Texas               76712
# ...

# %%
df_canada.shape
# Out:
# (100, 10)

# %%
df_IQFirms.shape
# Out:
# (37196, 13)

# %%
df_IQFirms.head()
# Out:
#       Ticker Security Name           Company Name Excel Company ID  \
# 0  NEOE:WFCS     CDR REG S  Wells Fargo & Company         IQ292891
# 1  NEOE:WFCS     CDR REG S  Wells Fargo & Company        IQ4292618
# 2  NEOE:WFCS     CDR REG S  Wells Fargo & Company        IQ4292618
# 3  NEOE:WFCS     CDR REG S  Wells Fargo & Company        IQ4292618
# 4  NEOE:WFCS     CDR REG S  Wells Fargo & Company        IQ4292618
#
#   Trading Status Most Recent Trade Price ($USD, Historical rate)  \
# 0         Active                                           16.05
# 1         Active                                           16.05
# 2         Active                                           16.05
# 3         Active                                           16.05
# 4         Active                                           16.05
#
#                 Equity Security Type Country/Region of Incorporation  \
# 0  Depository Receipt (Common Stock)                               -
# ...
